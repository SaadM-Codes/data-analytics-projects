# %% [markdown]
# <h2><b>Advanced extra tasks for extra points (varying challenges, some require Googling):</b></h2>

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# <ul>
# <li><b>2. Use the "titanic" dataset from the seaborn datasets
# (sns.load_dataset('titanic')).</b> Find out the features of a typical person
# that survived or did not survive the sinking of Titanic.</li>
# </ul>
#
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/titanic.png"/>

# %%
# code for the advanced extra task, you can also create a separate notebook for this 
# (might be a better idea, since a new dataset always adds quite much new code)

df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
correlation_matrix_3 = df.corr(numeric_only=True) 
correlation_matrix_3

sns.heatmap(correlation_matrix_3, annot= True, cmap="Greens")
# -0.56,-0.34, 0.26

# less not survived 
# not suvied 3 class 
# more you pay the better class you have survival rate increase
# Out:
# <Axes: >

# %%
# Question:  Find out the features of a typical person that survived or did not survive the sinking of Titanic

# Answer: People who most likely survived were mostly in first class and 
# were between ages of 5 and 60, adult male did not survived.
# people who likely did not survived were in 3 class or general class .

# %%
# to check which age group people survived

sns.scatterplot(x= "age", y="fare",hue="survived", data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.pairplot(df, hue="survived")
