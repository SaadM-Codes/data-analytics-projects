# %%
import json
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_json("testing.json")
df.head(5)
# Out:
#    id         name  value
# 0   1      Pannier    297
# 1   2   Voltsillam    388
# 2   3         Rank    501
# 3   4  Toughjoyfax    281
# 4   5      Cardify    319

# %%
from  flatten_json import flatten
